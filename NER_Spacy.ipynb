# %% [markdown]
# # NER (Named Entity Recognition)

# %%
from PIL import Image
from IPython.display import display
# Read the image
image = Image.open('NER.jpg')
# Display the image inline
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x391>

# %%
#@!pip install --upgrade spacy
import spacy
#!python -m spacy download en_core_web_sm

# %%
# !pip show spacy
# Out:
# Name: spacy
# Version: 3.7.5
# Summary: Industrial-strength Natural Language Processing (NLP) in Python
# Home-page: https://spacy.io
# Author: Explosion
# Author-email: contact@explosion.ai
# License: MIT
# Location: C:\Users\Sajib Saha\anaconda3\Lib\site-packages
# Requires: catalogue, cymem, jinja2, langcodes, murmurhash, numpy, packaging, preshed, pydantic, requests, setuptools, spacy-legacy, spacy-loggers, srsly, thinc, tqdm, typer, wasabi, weasel
# Required-by:

# %%
# !python -m spacy download en_core_web_sm
# Out:
# C:\Users\Sajib Saha\AppData\Local\Programs\Python\Python311\python.exe: No module named spacy

# %%
from spacy import displacy # a kind of visualazation tool
from collections import Counter # module to count the occurrences of items
nlp = spacy.load('en_core_web_sm')

doc = nlp(u'I spent $25 today')
print([(X.text, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 4
#       2 from spacy import displacy # a kind of visualazation tool
#       3 from collections import Counter # module to count the occurrences of items
# ----> 4 nlp = spacy.load('en_core_web_sm')
#       6 doc = nlp(u'I spent $25 today')
#       7 print([(X.text, X.ent_iob_, X.ent_type_) for X in doc])
#
# File ~\anaconda3\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
# ...
